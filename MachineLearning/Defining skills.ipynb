# %%
import pandas as pd
import matplotlib.pyplot as plt


mma_dataframe = pd.read_csv('masterdataframe.csv')

# %%
#Constants
TESTSIZE = 0.1  # % of data will be used for testing.
VALIDSPLITSIZE = 0.01  # % of data will be used for validation.
MIN_MATCH_COUNT = 2 # Minimum amount of matches player has to have done in order to be used in data

#Define features
staticFeatures = [
    "date",
    "method",
    "control",
    'fighter',
    'opponent',
    'division',
    "time_format",
    "result"
]
skillFeatures = [
    "ground_att",
    "ground_def",
    "standup_att",
    "standup_def",
    "fighter_score",
    "stamina",
    "fight_ratio",
    "winloseratio",
    "control_ratio"
]

extra_features = [
    "division",
    "control",
    "time",
    "method"
]

fightStr = "fighter"

#Import data
mma_dataframe = pd.read_csv('masterdataframe.csv', parse_dates=True)
mma_fights = mma_dataframe[staticFeatures]
fighters_list = pd.DataFrame(mma_dataframe.drop_duplicates(fightStr)[fightStr])
feature_cols = mma_dataframe.columns

#Prepare datasets
fighters_list["matchcount"] = fighters_list.fighter.map(mma_dataframe.fighter.value_counts())
fighters_list = fighters_list.drop_duplicates(fightStr)
fighters_list = fighters_list.set_index(fightStr)
selected_fighters = pd.DataFrame(fighters_list.index[fighters_list["matchcount"] > MIN_MATCH_COUNT])
mma_dataframe[['minutes', 'seconds']] = mma_dataframe['time'].str.split(':', expand=True)
mma_fights['time'] = pd.to_numeric(mma_dataframe['minutes']) * 60 + pd.to_numeric(mma_dataframe['seconds'])

def fighter_statistics(fighter): 
    # Prepare helper functions
    def col_for_fighter(col): return mma_dataframe[col][forFighter]
    def matchAfter(seconds): return mma_dataframe["total_comp_time"] > seconds
    def matchBefore(seconds): return mma_dataframe["total_comp_time"] <= seconds
    def normalize(score): return max(0, score)
    def minimumOne(value): return max(1, value)

    # Prepare multiuse variables
    forFighter = (mma_dataframe[fightStr] == fighter)                      # For specific fighter
    lost = (mma_dataframe["result"]==0)                                    # Lost match
    won = (mma_dataframe["result"]==1)                                     # Won match
    withSub = (mma_dataframe["method"]=="SUB")                             # By submission
    withKO = (mma_dataframe["method"]=="KO/TKO")                           # By KO
    result = (mma_dataframe["result"])                                     # Match outcome
    num_fights = fighters_list.loc[fighter]["matchcount"]                  # Number of fights
    matchtime_total = col_for_fighter("total_comp_time").sum()             # Total matchtime   
    ground_time = col_for_fighter("control").sum()                         # Control time
    standup_time = matchtime_total - col_for_fighter("control").sum()      # Standup time

    def fight_ratio():
        return ground_time / standup_time

    def total_wins():
        return won[forFighter].sum()

    def control_ratio():
        controls = col_for_fighter("control").mean()
        return (controls / num_fights) / 2

    def standup_att():
        knockdowns = col_for_fighter('knockdowns').sum()
        sig_strikes_accuracy = col_for_fighter('sig_strikes_landed').mean()
        total_strikes_accuracy = col_for_fighter('total_strikes_landed').mean()
        head_strikes_accuracy = col_for_fighter('head_strikes_landed').mean()
        body_strikes_accuracy = col_for_fighter('body_strikes_landed').mean()
        leg_strikes_accuracy = col_for_fighter('leg_strikes_landed').mean()
        distance_strikes_accuracy = col_for_fighter('distance_strikes_landed').mean()
        clinch_strikes_accuracy = col_for_fighter('clinch_strikes_landed').mean()

        return (sig_strikes_accuracy + total_strikes_accuracy + head_strikes_accuracy + body_strikes_accuracy + leg_strikes_accuracy + distance_strikes_accuracy + clinch_strikes_accuracy) / 8 + knockdowns * 0.1

    def stamina():
        win_second_round= result[forFighter & matchAfter(300) & matchBefore(600)].sum()
        win_third_round= result[forFighter & matchAfter(600) & matchBefore(900)].sum()
        win_champ_round= result[forFighter & matchAfter(900)].sum()

        fights_second_round= result[forFighter & matchAfter(300) & matchBefore(600)].count()
        fights_third_round= result[forFighter & matchAfter(600) & matchBefore(900)].count()
        fights_champ_round= result[forFighter & matchAfter(900)].count()

        total_stamina = np.array([
            (0.2 * win_second_round / minimumOne(fights_second_round)),
            (0.6 * win_third_round / minimumOne(fights_third_round)),
            (win_champ_round / minimumOne(fights_champ_round))
        ]).sum()
        return normalize(total_stamina)

    def winloseratio():
        last_three_won = won[forFighter][-20:].sum()
        last_three_lost = lost[forFighter][-20:].sum()
    
        if last_three_lost == 0: 
            return 1 
        else:
            return last_three_won / last_three_lost

    def standup_def():
        sig_strikes_def = col_for_fighter('sig_strikes_def').mean()
        total_strikes_def = col_for_fighter('total_strikes_def').mean()
        head_strikes_def = col_for_fighter('head_strikes_def').mean()
        body_strikes_def = col_for_fighter('body_strikes_def').mean()
        leg_strikes_def = col_for_fighter('leg_strikes_def').mean()
        distance_strikes_def = col_for_fighter('distance_strikes_def').mean()
        clinch_strikes_def = col_for_fighter('clinch_strikes_def').mean()

        return (sig_strikes_def + total_strikes_def + head_strikes_def + body_strikes_def + leg_strikes_def + distance_strikes_def + clinch_strikes_def) / 8

    def ground_att():
        avg_takedowns_accuracy = col_for_fighter('takedowns_landed').mean()
        ground_strikes_accuracy = col_for_fighter('ground_strikes_landed').mean()
        control = col_for_fighter('control').mean()
        sub_attempts = col_for_fighter('avg_sub_attempts').mean()
        ground_skill_score = (control + sub_attempts + avg_takedowns_accuracy + ground_strikes_accuracy) / 4

        return ground_skill_score

    def ground_def():
        takedowns_def = col_for_fighter('takedowns_def').mean()
        ground_strikes_def = col_for_fighter('ground_strikes_def').mean()
        reversals = col_for_fighter('reversals').mean()
        return (takedowns_def + ground_strikes_def + reversals) / 3
    
    def fighter_score():
        LAST_MATCHES = 4 # Use last x matches of fighter
        score = 0
        multiplier = 0.4
        results = col_for_fighter("result")
        for matchResult in results[:LAST_MATCHES:-1]:
            if matchResult == 1: # Won match
                score += multiplier
            else:
                score -= multiplier
            multiplier += 0.4
        return score
    
    return total_wins(), fight_ratio(), ground_att(), ground_def(), standup_att(), standup_def(), fighter_score(), stamina(), winloseratio(), control_ratio()

suffixFighter = "_fighter"
suffixOpponent = "_opponent"
mma_fights = mma_fights.merge(selected_fighters, on=fightStr, how='inner')
mma_fights = mma_fights.merge(selected_fighters, left_on="opponent", right_on="fighter", how="inner", suffixes=(suffixFighter,suffixOpponent))
mma_fights = mma_fights.drop(f'{fightStr}_opponent', axis=1)
mma_fights['fighter'] = mma_fights['fighter_fighter']

#Transform data for dates
#mma_fights['date'] = pd.to_datetime(mma_fights['date'], errors='coerce')
#mma_fights['date'] = mma_fights['date'].astype('int64') / 10 ** 9

#Transform data for fighter names


finalFeatures = skillFeatures
suffixed_features = [skill + suffixFighter for skill in finalFeatures] + [skill + suffixOpponent for skill in finalFeatures]
suffixed_features = suffixed_features + extra_features
# Out:
# /tmp/ipykernel_68200/2582356769.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mma_fights['time'] = pd.to_numeric(mma_dataframe['minutes']) * 60 + pd.to_numeric(mma_dataframe['seconds'])

# %%
import pandas as pd
import numpy as np

fighter_stats = {}
for fighter in selected_fighters[fightStr]:
    fighter_stats[fighter] = fighter_statistics(fighter)

fighter_stats_df = pd.DataFrame.from_dict(fighter_stats, orient='index', columns=['total_wins', 'fight_ratio', 'ground_att', 'ground_def', 'standup_att', 'standup_def', 'fighter_score', 'stamina', 'winloseratio', 'control_ratio'])

# Calculate the correlation matrix
correlation_matrix = fighter_stats_df.corr()

x = correlation_matrix.style.background_gradient(cmap='coolwarm').format(precision=2)

# %%
x
# Out:
# <style type="text/css">
# #T_dcc56_row0_col0, #T_dcc56_row1_col1, #T_dcc56_row2_col2, #T_dcc56_row3_col3, #T_dcc56_row4_col4, #T_dcc56_row5_col5, #T_dcc56_row6_col6, #T_dcc56_row7_col7, #T_dcc56_row8_col8, #T_dcc56_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_dcc56_row0_col1 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_dcc56_row0_col2, #T_dcc56_row3_col6 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_dcc56_row0_col3, #T_dcc56_row2_col0 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_dcc56_row0_col4 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_dcc56_row0_col5 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_dcc56_row0_col6 {
#   background-color: #f5a081;
#   color: #000000;
# }
# #T_dcc56_row0_col7 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_dcc56_row0_col8 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_dcc56_row0_col9, #T_dcc56_row4_col1, #T_dcc56_row5_col2, #T_dcc56_row5_col4, #T_dcc56_row9_col0, #T_dcc56_row9_col3, #T_dcc56_row9_col5, #T_dcc56_row9_col6, #T_dcc56_row9_col7, #T_dcc56_row9_col8 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_dcc56_row1_col0 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_dcc56_row1_col2 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_dcc56_row1_col3 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_dcc56_row1_col4 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_dcc56_row1_col5 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_dcc56_row1_col6 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_dcc56_row1_col7 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_dcc56_row1_col8 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_dcc56_row1_col9 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_dcc56_row2_col1 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_dcc56_row2_col3 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_dcc56_row2_col4, #T_dcc56_row5_col8 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_dcc56_row2_col5 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_dcc56_row2_col6 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_dcc56_row2_col7 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_dcc56_row2_col8, #T_dcc56_row5_col6 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_dcc56_row2_col9 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_dcc56_row3_col0 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_dcc56_row3_col1 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_dcc56_row3_col2 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_dcc56_row3_col4, #T_dcc56_row7_col5 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_dcc56_row3_col5 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_dcc56_row3_col7 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_dcc56_row3_col8, #T_dcc56_row6_col8 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_dcc56_row3_col9 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_dcc56_row4_col0 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_dcc56_row4_col2, #T_dcc56_row4_col6 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_dcc56_row4_col3, #T_dcc56_row6_col4 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_dcc56_row4_col5 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_dcc56_row4_col7 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_dcc56_row4_col8, #T_dcc56_row7_col2, #T_dcc56_row7_col3 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_dcc56_row4_col9, #T_dcc56_row6_col5 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_dcc56_row5_col0 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_dcc56_row5_col1 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_dcc56_row5_col3 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_dcc56_row5_col7 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_dcc56_row5_col9 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_dcc56_row6_col0 {
#   background-color: #f29072;
#   color: #f1f1f1;
# }
# #T_dcc56_row6_col1 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_dcc56_row6_col2, #T_dcc56_row7_col9 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_dcc56_row6_col3, #T_dcc56_row8_col2 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_dcc56_row6_col7 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_dcc56_row6_col9 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_dcc56_row7_col0 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_dcc56_row7_col1 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_dcc56_row7_col4 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_dcc56_row7_col6 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_dcc56_row7_col8, #T_dcc56_row8_col0 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_dcc56_row8_col1 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_dcc56_row8_col3, #T_dcc56_row8_col6 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_dcc56_row8_col4 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_dcc56_row8_col5 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_dcc56_row8_col7 {
#   background-color: #f5c4ac;
#   color: #000000;
# }
# #T_dcc56_row8_col9 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_dcc56_row9_col1 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_dcc56_row9_col2 {
#   background-color: #f29274;
#   color: #f1f1f1;
# }
# #T_dcc56_row9_col4 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_dcc56">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dcc56_level0_col0" class="col_heading level0 col0" >total_wins</th>
#       <th id="T_dcc56_level0_col1" class="col_heading level0 col1" >fight_ratio</th>
#       <th id="T_dcc56_level0_col2" class="col_heading level0 col2" >ground_att</th>
#       <th id="T_dcc56_level0_col3" class="col_heading level0 col3" >ground_def</th>
#       <th id="T_dcc56_level0_col4" class="col_heading level0 col4" >standup_att</th>
#       <th id="T_dcc56_level0_col5" class="col_heading level0 col5" >standup_def</th>
#       <th id="T_dcc56_level0_col6" class="col_heading level0 col6" >fighter_score</th>
#       <th id="T_dcc56_level0_col7" class="col_heading level0 col7" >stamina</th>
#       <th id="T_dcc56_level0_col8" class="col_heading level0 col8" >winloseratio</th>
#       <th id="T_dcc56_level0_col9" class="col_heading level0 col9" >control_ratio</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dcc56_level0_row0" class="row_heading level0 row0" >total_wins</th>
#       <td id="T_dcc56_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_dcc56_row0_col1" class="data row0 col1" >0.06</td>
#       <td id="T_dcc56_row0_col2" class="data row0 col2" >0.15</td>
#       <td id="T_dcc56_row0_col3" class="data row0 col3" >0.26</td>
#       <td id="T_dcc56_row0_col4" class="data row0 col4" >0.25</td>
#       <td id="T_dcc56_row0_col5" class="data row0 col5" >0.21</td>
#       <td id="T_dcc56_row0_col6" class="data row0 col6" >0.70</td>
#       <td id="T_dcc56_row0_col7" class="data row0 col7" >0.63</td>
#       <td id="T_dcc56_row0_col8" class="data row0 col8" >0.51</td>
#       <td id="T_dcc56_row0_col9" class="data row0 col9" >-0.33</td>
#     </tr>
#     <tr>
#       <th id="T_dcc56_level0_row1" class="row_heading level0 row1" >fight_ratio</th>
#       <td id="T_dcc56_row1_col0" class="data row1 col0" >0.06</td>
#       <td id="T_dcc56_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_dcc56_row1_col2" class="data row1 col2" >0.80</td>
#       <td id="T_dcc56_row1_col3" class="data row1 col3" >0.02</td>
#       <td id="T_dcc56_row1_col4" class="data row1 col4" >-0.11</td>
#       <td id="T_dcc56_row1_col5" class="data row1 col5" >-0.01</td>
#       <td id="T_dcc56_row1_col6" class="data row1 col6" >0.04</td>
#       <td id="T_dcc56_row1_col7" class="data row1 col7" >0.16</td>
#       <td id="T_dcc56_row1_col8" class="data row1 col8" >0.11</td>
#       <td id="T_dcc56_row1_col9" class="data row1 col9" >0.63</td>
#     </tr>
#     <tr>
#       <th id="T_dcc56_level0_row2" class="row_heading level0 row2" >ground_att</th>
#       <td i

# %%
mma_dataframe['ground_defence'] = (mma_dataframe['takedowns_def'] + mma_dataframe['ground_strikes_def'] + mma_dataframe['reversals'])
mma_dataframe['ground_attack'] = (mma_dataframe['takedowns_landed'] + mma_dataframe['sub_attempts'] + mma_dataframe['ground_strikes_landed'] + mma_dataframe['control'])
mma_dataframe['standup_defence'] = (mma_dataframe['sig_strikes_def'] + mma_dataframe['total_strikes_def'] + mma_dataframe['head_strikes_def'] + mma_dataframe['body_strikes_def'] + mma_dataframe['leg_strikes_def'] + mma_dataframe['distance_strikes_def'] + mma_dataframe['clinch_strikes_def'])
mma_dataframe['standup_attack'] = (mma_dataframe['sig_strikes_landed'] + mma_dataframe['total_strikes_landed'] + mma_dataframe['head_strikes_landed'] + mma_dataframe['body_strikes_landed'] + mma_dataframe['leg_strikes_landed'] + mma_dataframe['distance_strikes_landed'] + mma_dataframe['clinch_strikes_landed'])

mma_dataframe['stamina'] = (mma_dataframe['avg_takedowns_attempts_per_min'] + mma_dataframe['control'])

mma_dataframe['advantages'] = (mma_dataframe['height'] + mma_dataframe['reach'] + mma_dataframe['age'])

mma_dataframe['fight_ratio'] = mma_dataframe['control'] / (mma_dataframe['total_comp_time'] - mma_dataframe['control'])

mma_dataframe['total_skills'] = (mma_dataframe['fight_ratio'] + mma_dataframe['knockdowns'] +mma_dataframe['ground_defence'] + mma_dataframe['ground_attack'] + mma_dataframe['standup_defence'] + mma_dataframe['standup_attack']) 


lst = ['ground_defence', 'control', 'fight_ratio', 'stamina', 'ground_attack', 'standup_defence', 'standup_attack', 'total_skills', 'knockdowns', 'result']


chosen_mma_dataframe = mma_dataframe[lst]
corr = chosen_mma_dataframe.corr()

x = corr.style.background_gradient(cmap='coolwarm').format(precision=2)
x
# Out:
# <style type="text/css">
# #T_74665_row0_col0, #T_74665_row1_col1, #T_74665_row1_col3, #T_74665_row1_col4, #T_74665_row2_col2, #T_74665_row3_col1, #T_74665_row3_col3, #T_74665_row3_col4, #T_74665_row4_col1, #T_74665_row4_col3, #T_74665_row4_col4, #T_74665_row5_col5, #T_74665_row6_col6, #T_74665_row7_col7, #T_74665_row8_col8, #T_74665_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_74665_row0_col1, #T_74665_row5_col9 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_74665_row0_col2 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_74665_row0_col3, #T_74665_row0_col4 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_74665_row0_col5, #T_74665_row7_col0 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_74665_row0_col6 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_74665_row0_col7 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_74665_row0_col8 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_74665_row0_col9 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_74665_row1_col0, #T_74665_row1_col8, #T_74665_row2_col9, #T_74665_row3_col0, #T_74665_row3_col8, #T_74665_row4_col0, #T_74665_row5_col1, #T_74665_row5_col3, #T_74665_row5_col4, #T_74665_row5_col6, #T_74665_row6_col5, #T_74665_row8_col2, #T_74665_row8_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_74665_row1_col2, #T_74665_row3_col2 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_74665_row1_col5, #T_74665_row3_col5 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_74665_row1_col6, #T_74665_row3_col6 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_74665_row1_col7, #T_74665_row3_col7 {
#   background-color: #f7a688;
#   color: #000000;
# }
# #T_74665_row1_col9, #T_74665_row3_col9 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_74665_row2_col0 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_74665_row2_col1, #T_74665_row2_col3, #T_74665_row2_col4 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_74665_row2_col5 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_74665_row2_col6, #T_74665_row6_col0 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_74665_row2_col7 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_74665_row2_col8 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_74665_row4_col2 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_74665_row4_col5 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_74665_row4_col6, #T_74665_row9_col1, #T_74665_row9_col3 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_74665_row4_col7 {
#   background-color: #f6a385;
#   color: #000000;
# }
# #T_74665_row4_col8 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_74665_row4_col9 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_74665_row5_col0, #T_74665_row5_col7 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_74665_row5_col2, #T_74665_row7_col8 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_74665_row5_col8 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_74665_row6_col1, #T_74665_row6_col4 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_74665_row6_col2 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_74665_row6_col3 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_74665_row6_col7 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_74665_row6_col8 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_74665_row6_col9 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_74665_row7_col1, #T_74665_row7_col3 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_74665_row7_col2 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_74665_row7_col4 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_74665_row7_col5 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_74665_row7_col6 {
#   background-color: #f6bea4;
#   color: #000000;
# }
# #T_74665_row7_col9 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_74665_row8_col0 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_74665_row8_col1, #T_74665_row8_col3, #T_74665_row8_col4 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_74665_row8_col5 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_74665_row8_col6, #T_74665_row8_col9 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_74665_row9_col0 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_74665_row9_col2 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_74665_row9_col4 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_74665_row9_col5 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_74665_row9_col6 {
#   background-color: #a9c6fd;
#   color: #000000;
# }
# #T_74665_row9_col7 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_74665_row9_col8 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# </style>
# <table id="T_74665">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_74665_level0_col0" class="col_heading level0 col0" >ground_defence</th>
#       <th id="T_74665_level0_col1" class="col_heading level0 col1" >control</th>
#       <th id="T_74665_level0_col2" class="col_heading level0 col2" >fight_ratio</th>
#       <th id="T_74665_level0_col3" class="col_heading level0 col3" >stamina</th>
#       <th id="T_74665_level0_col4" class="col_heading level0 col4" >ground_attack</th>
#       <th id="T_74665_level0_col5" class="col_heading level0 col5" >standup_defence</th>
#       <th id="T_74665_level0_col6" class="col_heading level0 col6" >standup_attack</th>
#       <th id="T_74665_level0_col7" class="col_heading level0 col7" >total_skills</th>
#       <th id="T_74665_level0_col8" class="col_heading level0 col8" >knockdowns</th>
#       <th id="T_74665_level0_col9" class="col_heading level0 col9" >result</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_74665_level0_row0" class="row_heading level0 row0" >ground_defence</th>
#       <td id="T_74665_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_74665_row0_col1" class="data row0 col1" >-0.00</td>
#       <td id="T_74665_row0_col2" class="data row0 col2" >0.10</td>
#       <td id="T_74665_row0_col3" class="data row0 col3" >-0.00</td>
#       <td id="T_74665_row0_col4" class="data row0 col4" >0.00</td>
#       <td id="T_74665_row0_col5" class="data row0 col5" >0.31</td>
#       <td id="T_74665_row0_col6" class="data row0 col6" >0.09</td>
#       <td id="T_74665_row0_col7" class="data row0 col7" >0.39</td>
#       <td id="T_74665_row0_col8" class="data row0 col8" >0.21</td>
#       <td id="T_74665_row0_col9" class="data row0 col9" >0.36</td>
#     </tr>
#     <tr>
#       <th id="T_74665_level0_row1" class="row_heading level0 row1" >control</th>
#       <td id="T_74665_row1_col0" class="data row1 col0" >-0.00</td>
#       <td id="T_74665_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_74665_row1_col2" class="data row1 col2" >0.44</td>
#       <td id="T_74665_row1_col3" class="data row1 col3" >1.00</td>
#       <td id="T_74665_row1_col4" class="data row1 col4" >1.00</td>
#       <td id="T_74665_row1_col5" class="data row1 col5" >-0.10</td>
#       <td id="T_74665_row1_col6" class="data row1 col6" >0.25</td>
#       <td id="T_74665_row1_col7" class="data row1 col7" >0.73</td>
#       <td id="T_74665_row1_col8" class="data row1 col8" >-0.09</td>
#       <td id="T_74665_row1_col9" class="data row1 col9" >0.28</td>
#     </tr>
#     <tr>
#       <th id="T_74665_level0_row2" class="row_heading level0 row2" >fight_ratio</th>
#       <td id="T_74665_row2_col0" class="data row2 col0" >0.10</td>
#       <td id="T_74665_row2_col1" class="data row2 col1" >0.44</td>
#       <td id="T_74665_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_74665_row2_col3" class="data row2 col3" >0.44</td>
#       <td id="T_74665_row2_col4" class="data row2 col4" >0.45</td>
#       <td id="T_74665_row2_col5" class="data row2 col5" >0.09</td>
#       <td id="T_74665_row2_col6" class="data row2 col6" >-0.03</td>
#       <td id="T_74665_row2_col7" class="data row2 col7" >0.34</td>
#       <td id="T_74665_row2_col8" class="data row2 col8" >-0.06</td>
#       <td id="T_74665_row2_col9" class="data row2 col9" >0.19</td>
#     </tr>
#     <tr>
#       <th id="T_
